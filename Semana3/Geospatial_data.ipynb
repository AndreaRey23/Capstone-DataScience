# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.6/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from bs4) (4.6.3)

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from bs4 import BeautifulSoup

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(website_url)
My_table = soup.find('table',{'class':'wikitable sortable'})

# %% [markdown]
# **Tranform the data into a pandas dataframe**

# %%
Head = My_table.find_all('tr')
Table = []
for th in Head:
    row = np.array(th.getText()[1:-1].split('\n'))
    if row[1] != 'Not assigned': 
        if row[2] == 'Not assigned':
            row[2] = row[1]
        Table.append(row)
        
df_Canada = pd.DataFrame(data=Table[1:], columns=Table[0])
df_Canada.head()
# Out:
#   Postal Code             Borough                 Neighborhood
# 0         M1A                                     Not assigned
# 1         M2A                                     Not assigned
# 2         M3A          North York                    Parkwoods
# 3         M4A          North York             Victoria Village
# 4         M5A    Downtown Toronto    Regent Park, Harbourfront

# %%
Col = df_Canada.columns
Col
# Out:
# Index(['Postal Code', '', 'Borough', '', 'Neighborhood'], dtype='object')

# %%
Col = df_Canada.columns
df_Canada_Group = df_Canada.groupby(Col[0])[Col[4]].apply(lambda x: ''.join([str(elem+',') for elem in list(x)])).reset_index()
df_Canada_Group.head()
# Out:
#   Postal Code                             Neighborhood
# 0         M1A                            Not assigned,
# 1         M1B                          Malvern, Rouge,
# 2         M1C  Rouge Hill, Port Union, Highland Creek,
# 3         M1E       Guildwood, Morningside, West Hill,
# 4         M1G                                  Woburn,

# %% [markdown]
# The next task is essentially transforming this data of nested Python dictionaries into a pandas dataframe. So let's start by creating an empty dataframe.

# %%
# define the dataframe columns
column_names = ['Postal Code', 'Borough', 'Neighbourhood']

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
df_repeated = df_Canada.sort_values('Postal Code', ascending=True)
df_repeated.drop_duplicates('Postal Code', keep="last", inplace=True)
df_Canada_Group['Borough'] = df_repeated.reset_index()['Borough']

# %% [markdown]
# **Geospatial data**

# %%
# !pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 2.2MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from geocoder) (7.1.2)
# Collecting ratelim
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from geocoder) (1.12.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ratelim->geocoder) (4.4.2)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
# !wget -q -O 'postal_data.csv' http://cocl.us/Geospatial_data
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
df_csv = pd.read_csv('postal_data.csv')
df_csv.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_Canada_Group['Latitude'] = df_csv['Latitude']
df_Canada_Group['Longitude'] = df_csv['Longitude']
df_Canada_Group
# Out:
#     Postal Code                                       Neighborhood  \
# 0           M1A                                      Not assigned,
# 1           M1B                                    Malvern, Rouge,
# 2           M1C            Rouge Hill, Port Union, Highland Creek,
# 3           M1E                 Guildwood, Morningside, West Hill,
# 4           M1G                                            Woburn,
# 5           M1H                                         Cedarbrae,
# 6           M1J                               Scarborough Village,
# 7           M1K       Kennedy Park, Ionview, East Birchmount Park,
# 8           M1L                   Golden Mile, Clairlea, Oakridge,
# 9           M1M   Cliffside, Cliffcrest, Scarborough Village West,
# 10          M1N                       Birch Cliff, Cliffside West,
# 11          M1P  Dorset Park, Wexford Heights, Scarborough Town...
# 12          M1R                                 Wexford, Maryvale,
# 13          M1S                                         Agincourt,
# 14          M1T           Clarks Corners, Tam O'Shanter, Sullivan,
# 15          M1V  Milliken, Agincourt North, Steeles East, L'Amo...
# 16          M1W                     Steeles West, L'Amoreaux West,
# 17          M1X                                       Upper Rouge,
# 18          M1Y                                      Not assigned,
# 19          M1Z                                      Not assigned,
# 20          M2A                                      Not assigned,
# 21          M2B                                      Not assigned,
# 22          M2C                                      Not assigned,
# 23          M2E                                      Not assigned,
# 24          M2G                                      Not assigned,
# 25          M2H                                 Hillcrest Village,
# 26          M2J                      Fairview, Henry Farm, Oriole,
# 27          M2K                                   Bayview Village,
# 28          M2L                          York Mills, Silver Hills,
# 29          M2M                           Willowdale, Newtonbrook,
# 30          M2N                       Willowdale, Willowdale East,
# 31          M2P                                   York Mills West,
# 32          M2R                       Willowdale, Willowdale West,
# 33          M2S                                      Not assigned,
# 34          M2T                                      Not assigned,
# 35          M2V                                      Not assigned,
# 36          M2W                                      Not assigned,
# 37          M2X                                      Not assigned,
# 38          M2Y                                      Not assigned,
# 39          M2Z                                      Not assigned,
# 40          M3A                                         Parkwoods,
# 41          M3B                                         Don Mills,
# 42          M3C                                         Don Mills,
# 43          M3E                                      Not assigned,
# 44          M3G                                      Not assigned,
# 45          M3H   Bathurst Manor, Wilson Heights, Downsview North,
# 46          M3J                   Northwood Park, York University,
# 47          M3K                                         Downsview,
# 48          M3L                                         Downsview,
# 49          M3M                                         Downsview,
# 50          M3N                                         Downsview,
# 51          M3P                                      Not assigned,
# 52          M3R                                      Not assigned,
# 53          M3S                                      Not assigned,
# 54          M3T                                      Not assigned,
# 55          M3V                                      Not assigned,
# 56          M3W                                      Not assigned,
# 57          M3X                                      Not assigned,
# 58          M3Y                                      Not assigned,
# 59          M3Z                                      Not assigned,
# 60          M4A                                  Victoria Village,
# 61          M4B                   Parkview Hill, Woodbine Gardens,
# 62          M4C                                  Woodbine Heights,
# 63          M4E                                       The Beaches,
# 64          M4G                                           Leaside,
# 65          M4H                                  Thorncliffe Park,
# 66          M4J     East Toronto, Broadview North (Old East York),
# 67          M4K                      The Danforth West, Riverdale,
# 68          M4L                    India Bazaar, The Beaches West,
# 69          M4M                                   Studio District,
# 70          M4N                                     Lawrence Park,
# 71          M4P                                  Davisville North,
# 72          M4R                North Toronto West,  Lawrence Park,
# 73          M4S                                        Davisville,
# 74          M4T                       Moore Park, Summerhill East,
# 75          M4V  Summerhill West, Rathnelly, South Hill, Forest...
# 76          M4W                                          Rosedale,
# 77          M4X                       St. James Town, Cabbagetown,
# 78          M4Y                              Church and Wellesley,
# 79          M4Z                                      Not assigned,
# 80          M5A                         Regent Park, Harbourfront,
# 81          M5B                          Garden District, Ryerson,
# 82          M5C                                    St. James Town,
# 83          M5E                                       Berczy Park,
# 84          M5G                                Central Bay Street,
# 85          M5H                          Richmond, Adelaide, King,
# 86          M5J  Harbourfront East, Union Station, Toronto Isla...
# 87          M5K          Toronto Dominion Centre, Design Exchange,
# 88          M5L                    Commerce Court, Victoria Hotel,
# 89          M5M                 Bedford Park, Lawrence Manor East,
# 90          M5N                                          Roselawn,
# 91          M5P   Forest Hill North & West, Forest Hill Road Park,
# 92          M5R               The Annex, North Midtown, Yorkville,
# 93          M5S                    University of Toronto, Harbord,
# 94          M5T         Kensington Market, Chinatown, Grange Park,
# 95          M5V  CN Tower, King and Spadina, Railway Lands, Har...
# 96          M5W                                    Stn A PO Boxes,
# 97          M5X            First Canadian Place, Underground city,
# 98          M5Y                                      Not assigned,
# 99          M5Z                                      Not assigned,
# 100         M6A                  Lawrence Manor, Lawrence Heights,
# 101         M6B                                         Glencairn,
# 102         M6C                                Humewood-Cedarvale,
# 103         M6E                               Caledonia-Fairbanks,
# 104         M6G                                          Christie,
# 105         M6H                      Dufferin, Dovercourt Village,
# 106         M6J                          Little Portugal, Trinity,
# 107         M6K      Brockton, Parkdale Village, Exhibition Place,
# 108         M6L          North Park, Maple Leaf Park, Upwood Park,
# 109         M6M  Del Ray, Mount Dennis, Keelsdale and Silverthorn,
# 110         M6N                     Runnymede, The Junction North,
# 111         M6P                     High Park, The Junction South,
# 112         M6R                            Parkdale, Roncesvalles,
# 113         M6S                                Runnymede, Swansea,
# 114         M6T                                      Not assigned,
# 115         M6V                                      Not assigned,
# 116         M6W                                      Not assigned,
# 117         M6X                                      Not assigned,
# 118         M6Y                                      Not assigned,
# 119         M6Z                                      Not assigned,
# 120         M7A       Queen's Park, Ontario Provincial Government,
# 121         M7B                                      Not assigned,
# 122         M7C                                      Not assigned,
# 123         M7E                                      Not assigned,
# 124         M7G                                      Not assigned,
# 125         M7H                                      Not assigned,
# 126         M7J                                      Not assigned,
# 127         M7K                                      Not assigned,
# 128         M7L                                      Not assigned,
# 129         M7M                                      Not assigned,
# 130         M7N                                      Not assigned,
# 131         M7P                                      Not assigned,
# 132         M7R             Canada Post Gateway Processing Centre,
# 133         M7S                                      Not assigned,
# 134         M7T                                      Not assigned,
# 135         M7V                                      Not assigned,
# 136         M7W                                      Not assigned,
# 137         M7X                                      Not assigned,
# 138         M7Y  Business reply mail Processing Centre, South C...
# 139         M7Z                                      Not assigned,
# 140         M8A                                      Not assigned,
# 141         M8B                                      Not assigned,
# 142         M8C                                      Not assigned,
# 143         M8E                                      Not assigned,
# 144         M8G                                      Not assigned,
# 145         M8H                                      Not assigned,
# 146         M8J                                      Not assigned,
# 147         M8K                                      Not assigned,
# 148         M8L                                      Not assigned,
# 149         M8M                                      Not assigned,
# 150         M8N                                      Not assigned,
# 151         M8P                                      Not assigned,
# 152         M8R                                      Not assigned,
# 153         M8S                                      Not assigned,
# 154         M8T                                      Not assigned,
# 155         M8V      New Toronto, Mimico South, Humber Bay Shores,
# 156         M8W                            Alderwood, Long Branch,
# 157         M8X     The Kingsway, Montgomery Road, Old Mill North,
# 158         M8Y  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 159         M8Z  Mimico NW, The Queensway West, South of Bloor,...
# 160         M9A           Islington Avenue, Humber Valley Village,
# 161         M9B  West Deane Park, Princess Gardens, Martin Grov...
# 162         M9C  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 163         M9E                                      Not assigned,
# 164         M9G                                      Not assigned,
# 165         M9H                                      Not assigned,
# 166         M9J                                      Not assigned,
# 167         M9K                                      Not assigned,
# 168         M9L                                     Humber Summit,
# 169         M9M                                  Humberlea, Emery,
# 170         M9N                                            Weston,
# 171         M9P                                         Westmount,
# 172         M9R  Kingsview Village, St. Phillips, Martin Grove ...
# 173         M9S                                      Not assigned,
# 174         M9T                                      Not assigned,
# 175         M9V  South Steeles, Silverstone, Humbergate, Jamest...
# 176         M9W               Northwest, West Humber - Clairville,
# 177         M9X                                      Not assigned,
# 178         M9Y                                      Not assigned,
# 179         M9Z                                      Not assigned,
#
#               Borough   Latitude  Longitude
# 0                      43.806686 -79.194353
# 1         Scarborough  43.784535 -79.160497
# 2         Scarborough  43.763573 -79.188711
# 3         Scarborough  43.770992 -79.216917
# 4         Scarborough  43.773136 -79.239476
# 5         Scarborough  43.744734 -79.239476
# 6         Scarborough  43.727929 -79.262029
# 7         Scarborough  43.711112 -79.284577
# 8         Scarborough  43.716316 -79.239476
# 9         Scarborough  43.692657 -79.264848
# 10        Scarborough  43.757410 -79.273304
# 11        Scarborough  43.750072 -79.295849
# 12        Scarborough  43.794200 -79.262029
# 13        Scarborough  43.781638 -79.304302
# 14        Scarborough  43.815252 -79.284577
# 15        Scarborough  43.799525 -79.318389
# 16        Scarborough  43.836125 -79.205636
# 17        Scarborough  43.803762 -79.363452
# 18                     43.778517 -79.346556
# 19                     43.786947 -79.385975
# 20                     43.757490 -79.374714
# 21                     43.789053 -79.408493
# 22                     43.770120 -79.408493
# 23                     43.752758 -79.400049
# 24                     43.782736 -79.442259
# 25         North York  43.753259 -79.329656
# 26         North York  43.745906 -79.352188
# 27         North York  43.725900 -79.340923
# 28         North York  43.754328 -79.442259
# 29         North York  43.767980 -79.487262
# 30         North York  43.737473 -79.464763
# 31         North York  43.739015 -79.506944
# 32         North York  43.728496 -79.495697
# 33                     43.761631 -79.520999
# 34                     43.725882 -79.315572
# 35                     43.706397 -79.309937
# 36                     43.695344 -79.318389
# 37                     43.676357 -79.293031
# 38                     43.709060 -79.363452
# 39                     43.705369 -79.349372
# 40         North York  43.685347 -79.338106
# 41         North York  43.679557 -79.352188
# 42         North York  43.668999 -79.315572
# 43                     43.659526 -79.340923
# 44                     43.728020 -79.388790
# 45         North York  43.712751 -79.390197
# 46         North York  43.715383 -79.405678
# 47         North York  43.704324 -79.388790
# 48         North York  43.689574 -79.383160
# 49         North York  43.686412 -79.400049
# 50         North York  43.679563 -79.377529
# 51                     43.667967 -79.367675
# 52                     43.665860 -79.383160
# 53                     43.654260 -79.360636
# 54                     43.657162 -79.378937
# 55                     43.651494 -79.375418
# 56                     43.644771 -79.373306
# 57                     43.657952 -79.387383
# 58                     43.650571 -79.384568
# 59                     43.640816 -79.381752
# 60         North York  43.647177 -79.381576
# 61          East York  43.648198 -79.379817
# 62          East York  43.733283 -79.419750
# 63       East Toronto  43.711695 -79.416936
# 64          East York  43.696948 -79.411307
# 65          East York  43.672710 -79.405678
# 66          East York  43.662696 -79.400049
# 67       East Toronto  43.653206 -79.400049
# 68       East Toronto  43.628947 -79.394420
# 69       East Toronto  43.646435 -79.374846
# 70    Central Toronto  43.648429 -79.382280
# 71    Central Toronto  43.718518 -79.464763
# 72    Central Toronto  43.709577 -79.445073
# 73    Central Toronto  43.693781 -79.428191
# 74    Central Toronto  43.689026 -79.453512
# 75    Central Toronto  43.669542 -79.422564
# 76   Downtown Toronto  43.669005 -79.442259
# 77   Downtown Toronto  43.647927 -79.419750
# 78   Downtown Toronto  43.636847 -79.428191
# 79                     43.713756 -79.490074
# 80   Downtown Toronto  43.691116 -79.476013
# 81   Downtown Toronto  43.673185 -79.487262
# 82   Downtown Toronto  43.661608 -79.464763
# 83   Downtown Toronto  43.648960 -79.456325
# 84   Downtown Toronto  43.651571 -79.484450
# 85   Downtown Toronto  43.662301 -79.389494
# 86   Downtown Toronto  43.636966 -79.615819
# 87   Downtown Toronto  43.662744 -79.321558
# 88   Downtown Toronto  43.605647 -79.501321
# 89         North York  43.602414 -79.543484
# 90    Central Toronto  43.653654 -79.506944
# 91    Central Toronto  43.636258 -79.498509
# 92    Central Toronto  43.628841 -79.520999
# 93   Downtown Toronto  43.667856 -79.532242
# 94   Downtown Toronto  43.650943 -79.554724
# 95   Downtown Toronto  43.643515 -79.577201
# 96   Downtown Toronto  43.756303 -79.565963
# 97   Downtown Toronto  43.724766 -79.532242
# 98                     43.706876 -79.518188
# 99                     43.696319 -79.532242
# 100        North York  43.688905 -79.554724
# 101        North York  43.739416 -79.588437
# 102              York  43.706748 -79.594054
# 103              York        NaN        NaN
# 104  Downtown Toronto        NaN        NaN
# 105      West Toronto        NaN        NaN
# 106      West Toronto        NaN        NaN
# 107      West Toronto        NaN        NaN
# 108        North York        NaN        NaN
# 109              York        NaN        NaN
# 110              York        NaN        NaN
# 111      West Toronto        NaN        NaN
# 112      West Toronto        NaN        NaN
# 113      West Toronto        NaN        NaN
# 114                          NaN        NaN
# 115                          NaN        NaN
# 116                          NaN        NaN
# 117                          NaN        NaN
# 118                          NaN        NaN
# 119                          NaN        NaN
# 120  Downtown Toronto        NaN        NaN
# 121                          NaN        NaN
# 122                          NaN        NaN
# 123                          NaN        NaN
# 124                          NaN        NaN
# 125                          NaN        NaN
# 126                          NaN        NaN
# 127                          NaN        NaN
# 128                          NaN        NaN
# 129                          NaN        NaN
# 130                          NaN        NaN
# 131                          NaN        NaN
# 132       Mississauga        NaN        NaN
# 133                          NaN        NaN
# 134                          NaN        NaN
# 135                          NaN        NaN
# 136                          NaN        NaN
# 137                          NaN        NaN
# 138      East Toronto        NaN        NaN
# 139                          NaN        NaN
# 140                          NaN        NaN
# 141                          NaN        NaN
# 142                          NaN        NaN
# 143                          NaN        NaN
# 144                          NaN        NaN
# 145                          NaN        NaN
# 146                          NaN        NaN
# 147                          NaN        NaN
# 148                          NaN        NaN
# 149                          NaN        NaN
# 150                          NaN        NaN
# 151                          NaN        NaN
# 152                          NaN        NaN
# 153                          NaN        NaN
# 154                          NaN        NaN
# 155         Etobicoke        NaN        NaN
# 156         Etobicoke        NaN        NaN
# 157         Etobicoke        NaN        NaN
# 158         Etobicoke        NaN        NaN
# 159         Etobicoke        NaN        NaN
# 160         Etobicoke        NaN        NaN
# 161         Etobicoke        NaN        NaN
# 162         Etobicoke        NaN        NaN
# 163                          NaN        NaN
# 164                          NaN        NaN
# 165                          NaN        NaN
# 166                          NaN        NaN
# 167                          NaN        NaN
# 168        North York        NaN        NaN
# 169        North York        NaN        NaN
# 170              York        NaN        NaN
# 171         Etobicoke        NaN        NaN
# 172         Etobicoke        NaN        NaN
# 173                          NaN        NaN
# 174                          NaN        NaN
# 175         Etobicoke        NaN        NaN
# 176         Etobicoke        NaN        NaN
# 177                          NaN        NaN
# 178                          NaN        NaN
# 179                          NaN        NaN
